# %% [markdown]
# ### 실행이 되지 않는 유튜브 영상 row 제거

# %%
# !pip install pyarrow
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'e:\programdata\anaconda3\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from tqdm.auto import tqdm

# %% [markdown]
# #### data : youtube-trending-video-dataset KR

# %%
data_kr_1 = pd.read_csv('./data/KR_youtube_trending_data.csv')

# %%
data_kr_1.head()
# Out:
#       video_id                                             title  \
# 0  uq5LClQN3cE                                       안녕하세요 보겸입니다
# 1  I-ZbZCHsHD0                                부락토스의 계획 [총몇명 프리퀄]
# 2  9d7jNUjBoss                                   평생 반성하면서 살겠습니다.
# 3  3pI_L3-sMVg                              안녕하세요 꽈뚜룹입니다.
# 4  zrsBjYukE8s  박진영 (J.Y. Park) When We Disco (Duet with 선미) M/V
#
#             publishedAt                 channelId       channelTitle  \
# 0  2020-08-09T09:32:48Z  UCu9BCtGIEr73LXZsKmoujKw              보겸 BK
# 1  2020-08-12T09:00:08Z  UCRuSxVu4iqTK5kCh90ntAgA                총몇명
# 2  2020-08-10T09:54:13Z  UCMVC92EOs9yDJG5JS-CMesQ        양팡 YangPang
# 3  2020-08-11T15:00:58Z  UCkQCwnkQfgSuPTTnw_Y7v7w      꽈뚜룹 Quaddurup
# 4  2020-08-11T09:00:13Z  UCaO6TYtlC8U5ttz62hTrZgg  JYP Entertainment
#
#    categoryId         trending_date  \
# 0          24  2020-08-12T00:00:00Z
# 1           1  2020-08-12T00:00:00Z
# 2          22  2020-08-12T00:00:00Z
# ...

# %%
data_kr_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88954 entries, 0 to 88953
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           88954 non-null  object
#  1   title              88954 non-null  object
#  2   publishedAt        88954 non-null  object
#  3   channelId          88954 non-null  object
#  4   channelTitle       88954 non-null  object
#  5   categoryId         88954 non-null  int64
#  6   trending_date      88954 non-null  object
#  7   tags               88954 non-null  object
#  8   view_count         88954 non-null  int64
#  9   likes              88954 non-null  int64
#  10  dislikes           88954 non-null  int64
#  11  comment_count      88954 non-null  int64
#  12  thumbnail_link     88954 non-null  object
#  13  comments_disabled  88954 non-null  bool
#  14  ratings_disabled   88954 non-null  bool
#  15  description        87132 non-null  object
# ...

# %%
data_kr_1.drop_duplicates(subset=['video_id'], inplace = True, ignore_index = True)
data_kr_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11964 entries, 0 to 11963
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           11964 non-null  object
#  1   title              11964 non-null  object
#  2   publishedAt        11964 non-null  object
#  3   channelId          11964 non-null  object
#  4   channelTitle       11964 non-null  object
#  5   categoryId         11964 non-null  int64
#  6   trending_date      11964 non-null  object
#  7   tags               11964 non-null  object
#  8   view_count         11964 non-null  int64
#  9   likes              11964 non-null  int64
#  10  dislikes           11964 non-null  int64
#  11  comment_count      11964 non-null  int64
#  12  thumbnail_link     11964 non-null  object
#  13  comments_disabled  11964 non-null  bool
#  14  ratings_disabled   11964 non-null  bool
#  15  description        11685 non-null  object
# ...

# %%
data_kr_1
# Out:
#           video_id                                              title  \
# 0      uq5LClQN3cE                                        안녕하세요 보겸입니다
# 1      I-ZbZCHsHD0                                 부락토스의 계획 [총몇명 프리퀄]
# 2      9d7jNUjBoss                                    평생 반성하면서 살겠습니다.
# 3      3pI_L3-sMVg                               안녕하세요 꽈뚜룹입니다.
# 4      zrsBjYukE8s   박진영 (J.Y. Park) When We Disco (Duet with 선미) M/V
# ...            ...                                                ...
# 11959  oXrqDwF5x2c  캄보디아 한국어 열풍의 중심! 학생들의 존경 한 몸에 받는 한국어과 교수 [글로벌코...
# 11960  VpG0zN4BzgQ  역사는 짧지만, 열정은 가득! 코메니우스대학 한국학과 [글로벌코리안] / YTN k...
# 11961  Hx8Lc_0hUaI                       운동할 시간이 없다는 사람에게 보여주세요... 제발
# 11962  HvcQu_fYYls  소문난 잔치에 먹을 게 없다? 글래스고 기후회의 전격 분석 (KBS_237회_202...
# 11963  jpS728RkK18                행복한 왕자 [으스스한? 공포이야기 꿀냥툰🐈] ㅣ애니메이션ㅣ공포
#
#                 publishedAt                 channelId       channelTitle  \
# ...

# %%
chromedriver = 'E:\Documents\chromedriver\chromedriver.exe'
headless_options = webdriver.ChromeOptions()
headless_options.add_argument('headless')
# headless_options.add_argument('disable-gpu')

can_play = 0
can_play_list = []
cant_play = 0
cant_play_list = []
driver = webdriver.Chrome(chromedriver, options=headless_options)
# driver.get('https://www.youtube.com/watch?v=uq5LClQN3cE')
for video in tqdm(data_kr_1['video_id']):
    driver.get(f'https://www.youtube.com/watch?v={video}')
    try:
        tag = driver.find_element_by_css_selector('body > ytd-app > #content > #page-manager > ytd-watch-flexy > #columns > #primary > #primary-inner > #player > #error-screen > #container > yt-player-error-message-renderer') #> #player)
        print(f'재생 불가 : {video}')
        cant_play += 1
        cant_play_list.append(video)
    except NoSuchElementException:
#         print(f'재생 가능 : {video}')
        can_play += 1
        can_play_list.append(video)

print(cant_play)
print(cant_play_list)
# Out:
# ...
# 재생 불가 : 9d7jNUjBoss
# 재생 불가 : X-TPQPEyRGo
# 재생 불가 : kD16sKAlBnU
# 재생 불가 : fKWQDyKluUg
# 재생 불가 : jgHJEIajOeo
# 재생 불가 : Scx9QtRrcuU
# 재생 불가 : ZjTK3w8Ruhk
# 재생 불가 : mHawyysfFf4
# 재생 불가 : 4vmibeE9QyE
# 재생 불가 : IXUsSXvBu6o
# 재생 불가 : OJQA9cvJJJs
# 재생 불가 : 2eVl8K-oR1w
# 재생 불가 : M_OFpVEDqrI
# 재생 불가 : IOe0GGG2wcg
# 재생 불가 : MKVtK_MpwLk
# 재생 불가 : PtNGUFGkj98
# 재생 불가 : fKOJjBlXlX8
# 재생 불가 : pKPkjgFIxTo
# 재생 불가 : Dm0-kt2Fk0Q
# 재생 불가 : _ItHiLAy9VE
# 재생 불가 : 1H7Pf3O9kjI
# 재생 불가 : W20Ekg-4mrM
# 재생 불가 : IQASikpcBEI
# 재생 불가 : I4Z0_AygkJg
# 재생 불가 : lGLNB8Bulys
# 재생 불가 : nS2Bd651PqI
# 재생 불가 : r0SQf19cafc
# 재생 불가 : hdG4VCP1SXw
# 재생 불가 : a-A83UZcN9Y
# 재생 불가 : n4Mze8xD644
# 재생 불가 : jVcb35gSidw
# 재생 불가 : FQ6aHbXQ5vU
# 재생 불가 : -VdcQ4c7EXk
# 재생 불가 : W7hCEd3h3U8
# 재생 불가 : PFiTtVgYbL0
# 재생 불가 : FOUTh9FFmzQ
# 재생 불가 : x2hCYY68vH8
# 재생 불가 : tnlsLFq23D4
# 재생 불가 : dNaYuiUUrNM
# 재생 불가 : 4EhLf38jV_A
# 재생 불가 : c0PmxXaWt1I
# 재생 불가 : mFpu83GaSCo
# 재생 불가 : Vw3vAoPFjnU
# 재생 불가 : XikcXE1rniQ
# 재생 불가 : OSeYRL3_03E
# ...

# %%
# 재생 불가 영상
print(cant_play)
# Out:
# 424

# %%
data_kr_1 = data[data['video_id'].isin(can_play_list)]
data_kr_1.reset_index(drop = True, inplace = True)

# %%
data_kr_1.head()
# Out:
#       video_id                                             title  \
# 0  uq5LClQN3cE                                       안녕하세요 보겸입니다
# 1  I-ZbZCHsHD0                                부락토스의 계획 [총몇명 프리퀄]
# 2  3pI_L3-sMVg                              안녕하세요 꽈뚜룹입니다.
# 3  zrsBjYukE8s  박진영 (J.Y. Park) When We Disco (Duet with 선미) M/V
# 4  jbGRowa5tIk                         ITZY “Not Shy” M/V TEASER
#
#             publishedAt                 channelId       channelTitle  \
# 0  2020-08-09T09:32:48Z  UCu9BCtGIEr73LXZsKmoujKw              보겸 BK
# 1  2020-08-12T09:00:08Z  UCRuSxVu4iqTK5kCh90ntAgA                총몇명
# 2  2020-08-11T15:00:58Z  UCkQCwnkQfgSuPTTnw_Y7v7w      꽈뚜룹 Quaddurup
# 3  2020-08-11T09:00:13Z  UCaO6TYtlC8U5ttz62hTrZgg  JYP Entertainment
# 4  2020-08-11T15:00:13Z  UCaO6TYtlC8U5ttz62hTrZgg  JYP Entertainment
#
#    categoryId         trending_date  \
# 0          24  2020-08-12T00:00:00Z
# 1           1  2020-08-12T00:00:00Z
# 2          24  2020-08-12T00:00:00Z
# ...

# %%
data_kr_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11540 entries, 0 to 11539
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           11540 non-null  object
#  1   title              11540 non-null  object
#  2   publishedAt        11540 non-null  object
#  3   channelId          11540 non-null  object
#  4   channelTitle       11540 non-null  object
#  5   categoryId         11540 non-null  int64
#  6   trending_date      11540 non-null  object
#  7   tags               11540 non-null  object
#  8   view_count         11540 non-null  int64
#  9   likes              11540 non-null  int64
#  10  dislikes           11540 non-null  int64
#  11  comment_count      11540 non-null  int64
#  12  thumbnail_link     11540 non-null  object
#  13  comments_disabled  11540 non-null  bool
#  14  ratings_disabled   11540 non-null  bool
#  15  description        11303 non-null  object
# ...

# %%
data_kr_1.shape
# Out:
# (11540, 16)

# %%
data_kr_1.to_feather('./data/KR_youtube_trending_data_able.ftr')

# %% [markdown]
# #### data : youtube-trending-video-dataset US

# %%
data_us_1 = pd.read_csv('./data/US_youtube_trending_data.csv')

# %%
data_us_1.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
data_us_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91991 entries, 0 to 91990
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           91991 non-null  object
#  1   title              91991 non-null  object
#  2   publishedAt        91991 non-null  object
#  3   channelId          91991 non-null  object
#  4   channelTitle       91991 non-null  object
#  5   categoryId         91991 non-null  int64
#  6   trending_date      91991 non-null  object
#  7   tags               91991 non-null  object
#  8   view_count         91991 non-null  int64
#  9   likes              91991 non-null  int64
#  10  dislikes           91991 non-null  int64
#  11  comment_count      91991 non-null  int64
#  12  thumbnail_link     91991 non-null  object
#  13  comments_disabled  91991 non-null  bool
#  14  ratings_disabled   91991 non-null  bool
#  15  description        90597 non-null  object
# ...

# %%
data_us_1.drop_duplicates(subset=['video_id'], inplace = True, ignore_index = True)
data_us_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16111 entries, 0 to 16110
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           16111 non-null  object
#  1   title              16111 non-null  object
#  2   publishedAt        16111 non-null  object
#  3   channelId          16111 non-null  object
#  4   channelTitle       16111 non-null  object
#  5   categoryId         16111 non-null  int64
#  6   trending_date      16111 non-null  object
#  7   tags               16111 non-null  object
#  8   view_count         16111 non-null  int64
#  9   likes              16111 non-null  int64
#  10  dislikes           16111 non-null  int64
#  11  comment_count      16111 non-null  int64
#  12  thumbnail_link     16111 non-null  object
#  13  comments_disabled  16111 non-null  bool
#  14  ratings_disabled   16111 non-null  bool
#  15  description        15832 non-null  object
# ...

# %%
data_us_1
# Out:
#           video_id                                              title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 16106  2C2QoZqs5To               The 2 Dollar Bento Box | But Cheaper
# 16107  ZFmQrIZc_Xs  HYLO Open 2021 | Gideon/Sukamuljo (INA) [1] vs...
# 16108  Z8JVDwN7glo         I Spent 3,500,000,000 Candy Chasing Ghouls
# 16109  pLtTVazLSZo  Bordeaux vs PSG | LIGUE 1 HIGHLIGHTS | 11/06/2...
# 16110  ZrtXSGc9Wsg  HYLO Open 2021 | Puavaranukroh/Taerattanachai ...
#
#                 publishedAt                 channelId       channelTitle  \
# ...

# %%
chromedriver = 'E:\Documents\chromedriver\chromedriver.exe'
headless_options = webdriver.ChromeOptions()
headless_options.add_argument('headless')

can_play_us1 = 0
can_play_list_us1 = []
cant_play_us1 = 0
cant_play_list_us1 = []
driver = webdriver.Chrome(chromedriver, options=headless_options)
# driver.get('https://www.youtube.com/watch?v=uq5LClQN3cE')
for video in tqdm(data_us_1['video_id']):
    driver.get(f'https://www.youtube.com/watch?v={video}')
    try:
        tag = driver.find_element_by_css_selector('body > ytd-app > #content > #page-manager > ytd-watch-flexy > #columns > #primary > #primary-inner > #player > #error-screen > #container > yt-player-error-message-renderer') #> #player)
        print(f'재생 불가 : {video}')
        cant_play_us1 += 1
        cant_play_list_us1.append(video)
    except NoSuchElementException:
#         print(f'재생 가능 : {video}')
        can_play_us1 += 1
        can_play_list_us1.append(video)

print(cant_play_us1)
print(cant_play_list_us1)
# Out:
# ...
# 재생 불가 : mLOe7vGI0YI
# 재생 불가 : Que4RnxYLNc
# 재생 불가 : Aur7UgTGlL0
# 재생 불가 : PHYtv0v2DeA
# 재생 불가 : vysBEblWBoQ
# 재생 불가 : avgBgc210bg
# 재생 불가 : TUlFDVUTsKg
# 재생 불가 : qq7MSjXHRTU
# 재생 불가 : RsmttAEp9f4
# 재생 불가 : hT3pPAdnlfA
# 재생 불가 : Wc9_dsv5YYA
# 재생 불가 : kcynVTnaHw0
# 재생 불가 : 3bC2T0oFwoo
# 재생 불가 : JLsDWPsx23c
# 재생 불가 : A3VYsISvUy4
# 재생 불가 : wq5vHxY8kdU
# 재생 불가 : _J9Z74dQXrQ
# 재생 불가 : dYZlrfarCIs
# 재생 불가 : vwnyP6979xE
# 재생 불가 : tFZEP1z5Tr4
# 재생 불가 : qlDW7UPkon4
# 재생 불가 : De0kdCvJ2aA
# 재생 불가 : 9TS1euc3DVw
# 재생 불가 : vOpySfXMe6w
# 재생 불가 : kMXXL5fZTEY
# 재생 불가 : sE59kPlblPI
# 재생 불가 : sDBODXMrcj8
# 재생 불가 : gHPubcpGkrk
# 재생 불가 : nPiebsSuKCI
# 재생 불가 : qbUCnpJRCZg
# 재생 불가 : UrwRsuqhK88
# 재생 불가 : 2xPKE0koJtc
# 재생 불가 : ijHXi6jP4rI
# 재생 불가 : bmnSitmxk8c
# 재생 불가 : ZnCLJXclfn0
# 재생 불가 : Cj6AUuRs1A4
# 재생 불가 : 0BOjLXVdWsA
# 재생 불가 : kOf-mr8GNIc
# 재생 불가 : 1hpuFeNpLpI
# 재생 불가 : ympxn9Meq9E
# 재생 불가 : z6512XKKNkU
# 재생 불가 : C9I-W1eTCbk
# 재생 불가 : B0BWxxwA__s
# 재생 불가 : zS33yflGE_k
# 재생 불가 : oNCkWW6i3Ww
# ...

# %%
# 재생 불가 영상
print(cant_play_us1)
# Out:
# 925

# %%
data_us_1 = data_us_1[data_us_1['video_id'].isin(can_play_list_us1)]
data_us_1.reset_index(drop = True, inplace = True)

# %%
data_us_1.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#             publishedAt                 channelId   channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg            XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26
#
#           trending_date                                               tags  \
# ...

# %%
data_us_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15186 entries, 0 to 15185
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           15186 non-null  object
#  1   title              15186 non-null  object
#  2   publishedAt        15186 non-null  object
#  3   channelId          15186 non-null  object
#  4   channelTitle       15186 non-null  object
#  5   categoryId         15186 non-null  int64
#  6   trending_date      15186 non-null  object
#  7   tags               15186 non-null  object
#  8   view_count         15186 non-null  int64
#  9   likes              15186 non-null  int64
#  10  dislikes           15186 non-null  int64
#  11  comment_count      15186 non-null  int64
#  12  thumbnail_link     15186 non-null  object
#  13  comments_disabled  15186 non-null  bool
#  14  ratings_disabled   15186 non-null  bool
#  15  description        14916 non-null  object
# ...

# %%
data_us_1.shape
# Out:
# (15186, 16)

# %%
data_us_1.to_feather('./data/US_youtube_trending_data_able.ftr')

# %% [markdown]
# #### data : Trending YouTube Video Statistics KR

# %%
with open("./data/KRvideos.csv", "rt", encoding="utf8",errors='ignore') as f:
    data_kr_2 = pd.read_csv(f)

# %%
data_kr_2.head()
# Out:
#       video_id trending_date                       title channel_title  \
# 0  RxGQe4EeEpA      17.14.11          좋아 by 민서_윤종신_좋니 답가        라푸마코리아
# 1  hH7wVE8OlQ0      17.14.11            JSA 귀순 북한군 총격 부상        Edward
# 2  9V8bnWUmE9U      17.14.11  나몰라패밀리 운동화 영상 2탄 (빼빼로데이버젼)     나몰라패밀리 핫쇼
# 3  0_8py-t5R80      17.14.11  이명박 출국 현장, 놓치면 안되는 장면         미디어몽구
# 4  bk55RbxiQdI      17.14.11     김장겸은 물러갔다 MBC 노조 환호와 눈물        NocutV
#
#    category_id              publish_time  \
# 0           22  2017-11-13T07:07:36.000Z
# 1           25  2017-11-13T10:59:16.000Z
# 2           22  2017-11-11T07:16:08.000Z
# 3           25  2017-11-12T11:19:52.000Z
# 4           25  2017-11-13T11:08:59.000Z
#
#                                                 tags   views  likes  dislikes  \
# 0                      라푸마|"윤종신"|"좋니"|"좋아"|"샬레"|"민서"  156130   1422        40
# 1        JSA|"귀순"|"북한군"|"총격"|"부상"|"JSA 귀순 북한군 총격 부상"   76533    211        28
# ...

# %%
data_kr_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34567 entries, 0 to 34566
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                34567 non-null  object
#  1   trending_date           34567 non-null  object
#  2   title                   34567 non-null  object
#  3   channel_title           34567 non-null  object
#  4   category_id             34567 non-null  int64
#  5   publish_time            34567 non-null  object
#  6   tags                    34567 non-null  object
#  7   views                   34567 non-null  int64
#  8   likes                   34567 non-null  int64
#  9   dislikes                34567 non-null  int64
#  10  comment_count           34567 non-null  int64
#  11  thumbnail_link          34567 non-null  object
#  12  comments_disabled       34567 non-null  bool
#  13  ratings_disabled        34567 non-null  bool
# ...

# %%
data_kr_2.drop_duplicates(subset=['video_id'], inplace = True, ignore_index = True)
data_kr_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15876 entries, 0 to 15875
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                15876 non-null  object
#  1   trending_date           15876 non-null  object
#  2   title                   15876 non-null  object
#  3   channel_title           15876 non-null  object
#  4   category_id             15876 non-null  int64
#  5   publish_time            15876 non-null  object
#  6   tags                    15876 non-null  object
#  7   views                   15876 non-null  int64
#  8   likes                   15876 non-null  int64
#  9   dislikes                15876 non-null  int64
#  10  comment_count           15876 non-null  int64
#  11  thumbnail_link          15876 non-null  object
#  12  comments_disabled       15876 non-null  bool
#  13  ratings_disabled        15876 non-null  bool
# ...

# %%
data_kr_2
# Out:
#           video_id trending_date  \
# 0      RxGQe4EeEpA      17.14.11
# 1      hH7wVE8OlQ0      17.14.11
# 2      9V8bnWUmE9U      17.14.11
# 3      0_8py-t5R80      17.14.11
# 4      bk55RbxiQdI      17.14.11
# ...            ...           ...
# 15871  D5slHtZSvjY      18.14.06
# 15872  C2Aw5HoDJX0      18.14.06
# 15873  ckQpVlwY0Yk      18.14.06
# 15874  B1Jm5lBHLLc      18.14.06
# 15875  7niLVY31miI      18.14.06
#
#                                                    title channel_title  \
# 0                                     좋아 by 민서_윤종신_좋니 답가        라푸마코리아
# 1                                       JSA 귀순 북한군 총격 부상        Edward
# 2                             나몰라패밀리 운동화 영상 2탄 (빼빼로데이버젼)     나몰라패밀리 핫쇼
# 3                             이명박 출국 현장, 놓치면 안되는 장면         미디어몽구
# 4                                김장겸은 물러갔다 MBC 노조 환호와 눈물        NocutV
# ...                                                  ...           ...
# ...

# %%
chromedriver = 'E:\Documents\chromedriver\chromedriver.exe'
headless_options = webdriver.ChromeOptions()
headless_options.add_argument('headless')

can_play_kr2 = 0
can_play_list_kr2 = []
cant_play_kr2 = 0
cant_play_list_kr2 = []
driver = webdriver.Chrome(chromedriver, options=headless_options)
# driver.get('https://www.youtube.com/watch?v=uq5LClQN3cE')
for video in tqdm(data_kr_2['video_id']):
    driver.get(f'https://www.youtube.com/watch?v={video}')
    try:
        tag = driver.find_element_by_css_selector('body > ytd-app > #content > #page-manager > ytd-watch-flexy > #columns > #primary > #primary-inner > #player > #error-screen > #container > yt-player-error-message-renderer') #> #player)
        print(f'재생 불가 : {video}')
        cant_play_kr2 += 1
        cant_play_list_kr2.append(video)
    except NoSuchElementException:
#         print(f'재생 가능 : {video}')
        can_play_kr2 += 1
        can_play_list_kr2.append(video)

print(cant_play_kr2)
print(cant_play_list_kr2)
# Out:
# ...
# 재생 불가 : hH7wVE8OlQ0
# 재생 불가 : 4Nxb_nQDYWo
# 재생 불가 : iToRdbxuMtg
# 재생 불가 : 9dQ02l7YlQI
# 재생 불가 : 3NgzuR6mCT0
# 재생 불가 : _GQ2ymrME2Y
# 재생 불가 : gmavEUSx1eA
# 재생 불가 : 9r5ncSsv59I
# 재생 불가 : Ssx4JpUsW_U
# 재생 불가 : d5bsz2nJvrM
# 재생 불가 : O5V8CUj-fmg
# 재생 불가 : g0SNaoqC7Cg
# 재생 불가 : P9KQOvLRVNQ
# 재생 불가 : sZqZgEEB5SI
# 재생 불가 : uJTDJJ3BgMQ
# 재생 불가 : txg6RnfzM38
# 재생 불가 : m3AxIeQ3StA
# 재생 불가 : 6ZXFbgEVg1o
# 재생 불가 : JbIciJRSY10
# 재생 불가 : WyvtwqaWCy8
# 재생 불가 : vHdEl9deG4I
# 재생 불가 : cwcof34YxVQ
# 재생 불가 : _EdCoOqrj4s
# 재생 불가 : 4S4I1cUK2xw
# 재생 불가 : m3NzK_u9FMI
# 재생 불가 : JzYfGVwZ7dQ
# 재생 불가 : kJmJ_qTgBb8
# 재생 불가 : dRMuDqHp9dI
# 재생 불가 : Rd9SLEKpiYk
# 재생 불가 : xPreuX7D4PA
# 재생 불가 : hhzDPJdt42k
# 재생 불가 : pL0ryDuCH4k
# 재생 불가 : KcqZf5hb0sM
# 재생 불가 : Pd46Er8RWo0
# 재생 불가 : go8Y1X0ECZY
# 재생 불가 : zHfdgW4hy8A
# 재생 불가 : 59VIEKvKJA8
# 재생 불가 : XdVhT60Loxg
# 재생 불가 : cCOPLqDibfQ
# 재생 불가 : RcIPRBz998g
# 재생 불가 : hljD0ExqCh0
# 재생 불가 : 9XKpCpraezg
# 재생 불가 : enenslmbKJ4
# 재생 불가 : GdZBsz301yk
# 재생 불가 : 4CWYylzQh7g
# ...

# %%
# 재생 불가 영상
print(cant_play_kr2)
# Out:
# 7488

# %%
data_kr_2 = data_kr_2[data_kr_2['video_id'].isin(can_play_list_kr2)]
data_kr_2.reset_index(drop = True, inplace = True)

# %%
data_kr_2.head()
# Out:
#       video_id trending_date  \
# 0  RxGQe4EeEpA      17.14.11
# 1  9V8bnWUmE9U      17.14.11
# 2  0_8py-t5R80      17.14.11
# 3  bk55RbxiQdI      17.14.11
# 4  AmP0ryzDmbY      17.14.11
#
#                                               title channel_title  \
# 0                                좋아 by 민서_윤종신_좋니 답가        라푸마코리아
# 1                        나몰라패밀리 운동화 영상 2탄 (빼빼로데이버젼)     나몰라패밀리 핫쇼
# 2                        이명박 출국 현장, 놓치면 안되는 장면         미디어몽구
# 3                           김장겸은 물러갔다 MBC 노조 환호와 눈물        NocutV
# 4  김정숙 여사는 왜 갑자기 문재인 대통령 주머니에 손을 넣었나? 인도네시아 대통령도 깜놀           하우스
#
#    category_id              publish_time  \
# 0           22  2017-11-13T07:07:36.000Z
# 1           22  2017-11-11T07:16:08.000Z
# 2           25  2017-11-12T11:19:52.000Z
# 3           25  2017-11-13T11:08:59.000Z
# 4           25  2017-11-12T10:17:48.000Z
#
#                                                 tags   views  likes  dislikes  \
# ...

# %%
data_kr_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8388 entries, 0 to 8387
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                8388 non-null   object
#  1   trending_date           8388 non-null   object
#  2   title                   8388 non-null   object
#  3   channel_title           8388 non-null   object
#  4   category_id             8388 non-null   int64
#  5   publish_time            8388 non-null   object
#  6   tags                    8388 non-null   object
#  7   views                   8388 non-null   int64
#  8   likes                   8388 non-null   int64
#  9   dislikes                8388 non-null   int64
#  10  comment_count           8388 non-null   int64
#  11  thumbnail_link          8388 non-null   object
#  12  comments_disabled       8388 non-null   bool
#  13  ratings_disabled        8388 non-null   bool
# ...

# %%
data_kr_2.shape
# Out:
# (8388, 16)

# %%
data_kr_2.to_feather('./data/KRvideos_able.ftr')

# %% [markdown]
# ### data : Trending YouTube Video Statistics US

# %%
data_us_2 = pd.read_csv('./data/USvideos.csv')

# %%
data_us_2.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
data_us_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
data_us_2.drop_duplicates(subset=['video_id'], inplace = True, ignore_index = True)
data_us_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6351 entries, 0 to 6350
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                6351 non-null   object
#  1   trending_date           6351 non-null   object
#  2   title                   6351 non-null   object
#  3   channel_title           6351 non-null   object
#  4   category_id             6351 non-null   int64
#  5   publish_time            6351 non-null   object
#  6   tags                    6351 non-null   object
#  7   views                   6351 non-null   int64
#  8   likes                   6351 non-null   int64
#  9   dislikes                6351 non-null   int64
#  10  comment_count           6351 non-null   int64
#  11  thumbnail_link          6351 non-null   object
#  12  comments_disabled       6351 non-null   bool
#  13  ratings_disabled        6351 non-null   bool
# ...

# %%
data_us_2
# Out:
#          video_id trending_date  \
# 0     2kyS6SvSYSE      17.14.11
# 1     1ZAPwfrtAFY      17.14.11
# 2     5qpjK5DgCt4      17.14.11
# 3     puqaWrEC7tY      17.14.11
# 4     d380meD0W0M      17.14.11
# ...           ...           ...
# 6346  dS5Thrl-4Kc      18.14.06
# 6347  JGm9Y_hFqNk      18.14.06
# 6348  6h8QgZF5Qu4      18.14.06
# 6349  mpnshdmtE2Y      18.14.06
# 6350  yz7Xq3T0YPs      18.14.06
#
#                                                   title  \
# 0                    WE WANT TO TALK ABOUT OUR MARRIAGE
# 1     The Trump Presidency: Last Week Tonight with J...
# 2     Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                      Nickelback Lyrics: Real or Fake?
# 4                              I Dare You: GOING BALD!?
# ...                                                 ...
# 6346                      CRAYOLA MAKEUP | HIT OR MISS?
# 6347  First Take reacts: Kyrie Irving says contract ...
# 6348  Drop the Mic w/ Ashton Kutcher & Sean Diddy Combs
# ...

# %%
chromedriver = 'E:\Documents\chromedriver\chromedriver.exe'
headless_options = webdriver.ChromeOptions()
headless_options.add_argument('headless')

can_play_us2 = 0
can_play_list_us2 = []
cant_play_us2 = 0
cant_play_list_us2 = []
driver = webdriver.Chrome(chromedriver, options=headless_options)
# driver.get('https://www.youtube.com/watch?v=uq5LClQN3cE')
for video in tqdm(data_us_2['video_id']):
    driver.get(f'https://www.youtube.com/watch?v={video}')
    try:
        tag = driver.find_element_by_css_selector('body > ytd-app > #content > #page-manager > ytd-watch-flexy > #columns > #primary > #primary-inner > #player > #error-screen > #container > yt-player-error-message-renderer') #> #player)
        print(f'재생 불가 : {video}')
        cant_play_us2 += 1
        cant_play_list_us2.append(video)
    except NoSuchElementException:
#         print(f'재생 가능 : {video}')
        can_play_us2 += 1
        can_play_list_us2.append(video)

print(cant_play_us2)
print(cant_play_list_us2)
# Out:
# ...
# 재생 불가 : 5qpjK5DgCt4
# 재생 불가 : VifQlJit6A0
# 재생 불가 : n30k5CwLhS4
# 재생 불가 : CBVGjS_EJok
# 재생 불가 : hz7ukDjuq4w
# 재생 불가 : dQvIbulWCM4
# 재생 불가 : 069D0NmW39o
# 재생 불가 : 9XSULcLI6Hg
# 재생 불가 : Jw1Y-zhQURU
# 재생 불가 : cccyOn99s4Y
# 재생 불가 : ObIQ0s02UHg
# 재생 불가 : _Iz83-Cmt6A
# 재생 불가 : RYs08kX3Ih4
# 재생 불가 : 6nJw-jPQYVI
# 재생 불가 : zy0b9e40tK8
# 재생 불가 : 5Smb3tZD1Qc
# 재생 불가 : bhoFXkVy8JA
# 재생 불가 : fIQ2Ty2OL34
# 재생 불가 : hX643KbiI4s
# 재생 불가 : wRGldR_SQAA
# 재생 불가 : zYWt2mnalP8
# 재생 불가 : TSqwDQHE1J8
# 재생 불가 : XrDlDj9DfZs
# 재생 불가 : yZGSIpcAfEo
# 재생 불가 : 0zk2SwmCpss
# 재생 불가 : wwZ-T_WQ03A
# 재생 불가 : ijJPFowBsBc
# 재생 불가 : HBS9783c0BI
# 재생 불가 : Mn-3c6of8t8
# 재생 불가 : mcqWcLDUeag
# 재생 불가 : upEIZAihcwo
# 재생 불가 : aAm6AHr14zY
# 재생 불가 : 3x0usYgljOk
# 재생 불가 : GKUE2U2qlzY
# 재생 불가 : 8tbQHHso0oY
# 재생 불가 : Nz0qoOgyWSQ
# 재생 불가 : UC34HrZhfPM
# 재생 불가 : cDDF4pPwEUU
# 재생 불가 : J7wMOb0WIfQ
# 재생 불가 : QaASZecxQww
# 재생 불가 : FvoPOdop0hA
# 재생 불가 : p7KHGUwqF24
# 재생 불가 : CvpwGru3s7s
# 재생 불가 : aKPz583WRpQ
# 재생 불가 : n6xzsLDzyBk
# ...

# %%
# 재생 불가 영상
print(cant_play_us2)
# Out:
# 612

# %%
data_us_2 = data_us_2[data_us_2['video_id'].isin(can_play_list_us2)]
data_us_2.reset_index(drop = True, inplace = True)

# %%
data_us_2.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  puqaWrEC7tY      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  gHZ1Qz0KiKM      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 3                           I Dare You: GOING BALD!?               nigahiga
# 4                              2 Weeks with iPhone X               iJustine
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           24  2017-11-13T11:00:04.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           28  2017-11-13T19:07:23.000Z
#
# ...

# %%
data_us_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5739 entries, 0 to 5738
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                5739 non-null   object
#  1   trending_date           5739 non-null   object
#  2   title                   5739 non-null   object
#  3   channel_title           5739 non-null   object
#  4   category_id             5739 non-null   int64
#  5   publish_time            5739 non-null   object
#  6   tags                    5739 non-null   object
#  7   views                   5739 non-null   int64
#  8   likes                   5739 non-null   int64
#  9   dislikes                5739 non-null   int64
#  10  comment_count           5739 non-null   int64
#  11  thumbnail_link          5739 non-null   object
#  12  comments_disabled       5739 non-null   bool
#  13  ratings_disabled        5739 non-null   bool
# ...

# %%
data_us_2.shape
# Out:
# (5739, 16)

# %%
data_us_2.to_feather('./data/USvideos_able.ftr')
